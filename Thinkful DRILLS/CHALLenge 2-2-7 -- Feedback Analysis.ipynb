# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import os
import scipy
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns

print(os.getcwd())
# Out:
# C:\Users\rjourney\Desktop\Jupyter Drills\Thinkful DRILLS

# %%
fname = "amazon_cells_labelled.csv"
df = pd.read_csv(fname, delimiter= '\t', header=None)
df.columns = ['Review', 'Sentiment']

df['Review']=df['Review'].str.lower()

df['Review'] = df['Review'].str.replace('.', ' ', regex=True)

# %%
def print_full(x):
    pd.set_option('display.max_rows', len(x))
    pd.set_option('display.max_columns', None)
    pd.set_option('display.width', 2000)
    pd.set_option('display.float_format', '{:20,.2f}'.format)
    pd.set_option('display.max_colwidth', -1)
    print(x)
    pd.reset_option('display.max_rows')
    pd.reset_option('display.max_columns')
    pd.reset_option('display.width')
    pd.reset_option('display.float_format')
    pd.reset_option('display.max_colwidth')

print_full(df)
# Out:
#                                                                                                                                                     Review  Sentiment
# 0    so there is no way for me to plug it in here in the us unless i go by a converter                                                                      0
# 1    good case, excellent value                                                                                                                             1
# 2    great for the jawbone                                                                                                                                  1
# 3    tied to charger for conversations lasting more than 45 minutes major problems!!                                                                        0
# 4    the mic is great                                                                                                                                       1
# ...

# %%
keywords = ['good', 'excellent', 'awesome', 'nice', 'great', 'super', 'fantastic', 
            'amazing', 'perfect', 'recommend', 'thanks', 'quality', 'well', 'works', 'phone']

for key in keywords:
    # Note that we add spaces around the key so that we're getting the word,
    # not just pattern matching.
    df[str(key)] = df.Review.str.contains(
        str(key),
        case=False
    )
    
df.head()
# Out:
#                                               Review  Sentiment   good  \
# 0  so there is no way for me to plug it in here i...          0  False
# 1                        good case, excellent value           1   True
# 2                             great for the jawbone           1  False
# 3  tied to charger for conversations lasting more...          0  False
# 4                                  the mic is great           1  False
#
#    excellent  awesome   nice  great  super  fantastic  amazing  perfect  \
# 0      False    False  False  False  False      False    False    False
# 1       True    False  False  False  False      False    False    False
# 2      False    False  False   True  False      False    False    False
# 3      False    False  False  False  False      False    False    False
# 4      False    False  False   True  False      False    False    False
#
#    recommend  thanks  quality   well  works  phone
# 0      False   False    False  False  False  False
# ...

# %%
data = df[keywords]
target = df['Sentiment']

data.head()
# Out:
#     good  excellent  awesome   nice  great  super  fantastic  amazing  \
# 0  False      False    False  False  False  False      False    False
# 1   True       True    False  False  False  False      False    False
# 2  False      False    False  False   True  False      False    False
# 3  False      False    False  False  False  False      False    False
# 4  False      False    False  False   True  False      False    False
#
#    perfect  recommend  thanks  quality   well  works  phone
# 0    False      False   False    False  False  False  False
# 1    False      False   False    False  False  False  False
# 2    False      False   False    False  False  False  False
# 3    False      False   False    False  False  False  False
# 4    False      False   False    False  False  False  False

# %%
target.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    0
# 4    1
# Name: Sentiment, dtype: int64

# %%
# Our data is binary / boolean, so we're importing the Bernoulli classifier.
from sklearn.naive_bayes import BernoulliNB

# Instantiate our model and store it in a new variable.
bnb = BernoulliNB()

# Fit our model to the data.
bnb.fit(data, target)

# Classify, storing the result in a new variable.
y_pred = bnb.predict(data)

# Display our results.
print("Number of mislabeled points out of a total {} points : {}".format(
    data.shape[0],
    (target != y_pred).sum()
))
# Out:
# Number of mislabeled points out of a total 1000 points : 279

# %%
df_good = df[df['Sentiment'] == 1]

# %%
df_good['Review'].str.split(expand=True).stack().value_counts()
# Out:
# the                239
# and                188
# i                  154
# is                 140
# it                 122
# a                  105
# this               102
# to                  86
# great               80
# phone               78
# my                  72
# very                69
# for                 65
# with                63
# good                61
# of                  49
# works               45
# on                  44
# have                38
# was                 36
# in                  34
# that                31
# well                30
# headset             29
# quality             29
# product             28
# so                  26
# sound               25
# has                 24
# excellent           23
#                   ...
# carried              1
# sides                1
# travled              1
# purchasing           1
# all!                 1
# auto-answer          1
# weight,              1
# destroying           1
# prompt               1
# ...
