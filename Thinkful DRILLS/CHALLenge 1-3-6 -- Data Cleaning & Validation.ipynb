# %%
import pandas as pd
import numpy as np
import scipy
import os
import matplotlib.pyplot as plt
import seaborn as sns
import codecs
# %matplotlib inline

print(os.getcwd())
# Out:
# C:\Users\rjourney\Desktop\Jupyter Drills\Thinkful DRILLS

# %%
fname = "WELLCOME_APCspend2013_forThinkful.csv"
df = pd.read_csv(fname, encoding = "ISO-8859-1")

# %%
df.head()
# Out:
#               PMID/PMCID Publisher           Journal title  \
# 0                    NaN       CUP  Psychological Medicine
# 1             PMC3679557       ACS       Biomacromolecules
# 2  23043264  PMC3506128        ACS              J Med Chem
# 3    23438330 PMC3646402       ACS              J Med Chem
# 4   23438216 PMC3601604        ACS              J Org Chem
#
#                                        Article title  \
# 0  Reduced parahippocampal cortical thickness in ...
# 1  Structural characterization of a Model Gram-ne...
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...
# 3  Orvinols with mixed kappa/mu opioid receptor a...
# 4  Regioselective opening of myo-inositol orthoes...
#
#   COST (£) charged to Wellcome (inc VAT when charged)
# 0                                              £0.00
# 1                                           £2381.04
# 2                                            £642.56
# 3                                            £669.64
# ...

# %%
df.shape
# Out:
# (2127, 5)

# %%
df.columns
# Out:
# Index(['PMID/PMCID', 'Publisher', 'Journal title', 'Article title',
#        'COST (£) charged to Wellcome (inc VAT when charged)'],
#       dtype='object')

# %%
cols = ['PMID/PMCID', 'Publisher', 'Journal title', 'Article title',
       'COST (£) charged to Wellcome (inc VAT when charged)']

# %%
for col in cols:
    print('column: {}'.format(col))
    print(type(col))
# Out:
# column: PMID/PMCID
# <class 'str'>
# column: Publisher
# <class 'str'>
# column: Journal title
# <class 'str'>
# column: Article title
# <class 'str'>
# column: COST (£) charged to Wellcome (inc VAT when charged)
# <class 'str'>

# %%
df.isnull().sum().sort_values(ascending = False).head(32)
# Out:
# PMID/PMCID                                             199
# Journal title                                            1
# COST (£) charged to Wellcome (inc VAT when charged)      0
# Article title                                            0
# Publisher                                                0
# dtype: int64

# %%
df['Journal title'].unique()
# Out:
# array(['Psychological Medicine', 'Biomacromolecules', 'J Med Chem',
#        'J Org Chem', 'Journal of Medicinal Chemistry',
#        'Journal of Proteome Research', 'Mol Pharm',
#        'ACS Chemical Biology',
#        'Journal of Chemical Information and Modeling', 'Biochemistry',
#        'Gastroenterology', 'Journal of Biological Chemistry',
#        'Journal of Immunology', 'ACS Chemical Neuroscience', 'ACS NANO',
#        'American Chemical Society', 'Analytical Chemistry',
#        'Bioconjugate Chemistry', 'Journal of Medicinal Chemistry ',
#        'Journal of the American Chemical Society', 'ACS Nano', 'CHEST',
#        'Journal of Neurophysiology', 'Journal of Physiology',
#        'The Journal of Neurophysiology', 'American Journal of Psychiatry',
#        'Americal Journal of Psychiatry', 'Behavioral Neuroscience',
#        'Emotion', 'Health Psychology', 'Journal of Abnormal Psychology',
#        'Journal of Consulting and Clinical Psychology',
# ...

# %%
df = df.dropna()

# %%
df.isnull().sum().sort_values(ascending = False).head(32)
# Out:
# COST (£) charged to Wellcome (inc VAT when charged)    0
# Article title                                          0
# Journal title                                          0
# Publisher                                              0
# PMID/PMCID                                             0
# dtype: int64

# %%
print('Filtering the whole series:')
# Out:
# Filtering the whole series:

# %%
Wellcome = pd.Series(['PMID/PMCID', 'Publisher', 'Journal title', 'Article title',
       'COST (£) charged to Wellcome (inc VAT when charged)'])
print(Wellcome.apply(lambda x: str(x).isdigit()))
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df.describe()
# Out:
#        PMID/PMCID Publisher Journal title  \
# count        1928      1928          1928
# unique       1880       272           902
# top             -  Elsevier      PLoS One
# freq            7       344            91
#
#                                             Article title  \
# count                                                1928
# unique                                               1928
# top     Lovastatin for adult patients with dengue: pro...
# freq                                                    1
#
#        COST (£) charged to Wellcome (inc VAT when charged)
# count                                                1928
# unique                                               1295
# top                                              £2040.00
# freq                                                   90

# %%
df['Journal title'] = df['Journal title'].str.upper()

# %%
df["Journal title"].value_counts()
# Out:
# PLOS ONE                                                      188
# JOURNAL OF BIOLOGICAL CHEMISTRY                                52
# NEUROIMAGE                                                     28
# PLOS PATHOGENS                                                 24
# PLOS GENETICS                                                  23
# NUCLEIC ACIDS RESEARCH                                         22
# PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCES                20
# PLOS NEGLECTED TROPICAL DISEASES                               20
# NATURE COMMUNICATIONS                                          19
# HUMAN MOLECULAR GENETICS                                       17
# BMC PUBLIC HEALTH                                              12
# MOVEMENT DISORDERS                                             11
# BRAIN                                                          11
# JOURNAL OF GENERAL VIROLOGY                                    11
# ...

# %%
df['COST (£) charged to Wellcome (inc VAT when charged)']
# Out:
# 1       2381.04
# 2        642.56
# 3        669.64
# 4        685.88
# 5       2392.20
# 6       2367.95
# 7        649.33
# 8       1294.59
# 9       1294.78
# 10      1329.69
# 11      1287.20
# 12      1324.66
# 13       665.64
# 14      1006.72
# 15       238.08
# 16       265.67
# 17      2035.00
# 18      3108.08
# 19      1267.76
# 20      2286.73
# 22      1186.80
# 23       642.89
# 24      1533.29
# 25      2082.74
# 26      2314.10
# 27       759.67
# 28      1565.26
# 29       572.74
# 30       750.66
# 31       321.12
#          ...
# 2097    2236.02
# 2098    2275.02
# 2099    2373.57
# 2100     791.19
# 2101    1551.49
# 2102    1961.68
# 2103    1982.35
# 2104    2239.22
# 2105    2377.65
# 2106    2272.15
# 2107    1900.70
# 2108    3026.17
# 2109    1851.15
# 2110    1812.89
# 2111    1816.70
# 2112    2168.05
# 2113    1409.96
# 2114    2400.00
# 2115    1968.63
# 2116    2015.72
# 2117    1836.92
# 2118    1836.92
# 2119    1375.80
# 2120    1836.92
# ...

# %%
df['COST (£) charged to Wellcome (inc VAT when charged)'] = df['COST (£) charged to Wellcome (inc VAT when charged)'].str.replace('£', '')

# %%
df['COST (£) charged to Wellcome (inc VAT when charged)'] = df['COST (£) charged to Wellcome (inc VAT when charged)'].str.replace('$', '')

# %%
df['COST (£) charged to Wellcome (inc VAT when charged)'] = pd.to_numeric(df['COST (£) charged to Wellcome (inc VAT when charged)'])
#This function changes from a string to a numeric value

# %%
df['COST (£) charged to Wellcome (inc VAT when charged)'].mean()
# Out:
# 22729.969891078883

# %%
df['COST (£) charged to Wellcome (inc VAT when charged)'].median()
# Out:
# 1868.81

# %%
df['COST (£) charged to Wellcome (inc VAT when charged)'].std()
# Out:
# 142424.45480961062
